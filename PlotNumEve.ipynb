# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
x_final = 2
x_init = -x_final
x_steps = 40

# %% [markdown]
# ## FD

# %%
x_arr = []

"""
ee
"""
yu_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    x_arr.append(x)
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_ee_arr.append(y)

yd_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_ee_arr.append(y)

ys_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = x
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_ee_arr.append(y)

yueqd_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_ee_arr.append(y)

yueqmd_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = -x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_ee_arr.append(y)

"""
emu
"""
yu_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_emu_arr.append(y)

yd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_emu_arr.append(y)

ys_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = x
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_emu_arr.append(y)

yueqd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_emu_arr.append(y)

yueqmd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = -x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_emu_arr.append(y)

"""
etau
"""
yu_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_etau_arr.append(y)

yd_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_etau_arr.append(y)

ys_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = x
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_etau_arr.append(y)

yueqd_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_etau_arr.append(y)

yueqmd_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = -x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_etau_arr.append(y)

"""
mumu
"""
yu_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_mumu_arr.append(y)

yd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_mumu_arr.append(y)

ys_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = x
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_mumu_arr.append(y)

yueqd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_mumu_arr.append(y)

yueqmd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = -x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_mumu_arr.append(y)

"""
mutau
"""
yu_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_mutau_arr.append(y)

yd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_mutau_arr.append(y)

ys_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = x
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_mutau_arr.append(y)

yueqd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_mutau_arr.append(y)

yueqmd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = -x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_mutau_arr.append(y)

"""
tautau
"""
yu_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_tautau_arr.append(y)

yd_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_tautau_arr.append(y)

ys_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = x
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_tautau_arr.append(y)

yueqd_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_tautau_arr.append(y)

yueqmd_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = -x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NFD(*arguments)+NbarFD(*arguments)
    NSM = NFD(*np.zeros(18))+NbarFD(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_tautau_arr.append(y)

# %%
plt.rc('font', size=18)
fig, ax = plt.subplots(3,2,figsize=(16, 20))

"""
ee
"""
ax[0,0].plot(x_arr,yu_ee_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0,0].plot(x_arr,yd_ee_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0,0].plot(x_arr,ys_ee_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0,0].plot(x_arr,yueqd_ee_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0,0].plot(x_arr,yueqmd_ee_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0,0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0,0].set_xlabel(r'$\epsilon_{ee}^{Aq}$')
ax[0,0].set_ylabel(r'$(\mathcal{N}^{\rm FD}-\mathcal{N}_{\rm SM}^{\rm FD})/\mathcal{N}_{\rm SM}^{\rm FD}$')
ax[0,0].legend(loc=0)

"""
emu
"""
ax[0,1].plot(x_arr,yu_emu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0,1].plot(x_arr,yd_emu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0,1].plot(x_arr,ys_emu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0,1].plot(x_arr,yueqd_emu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0,1].plot(x_arr,yueqmd_emu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0,1].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0,1].set_xlabel(r'$\epsilon_{e\mu}^{Aq}$')
ax[0,1].set_ylabel(r'$(\mathcal{N}^{\rm FD}-\mathcal{N}_{\rm SM}^{\rm FD})/\mathcal{N}_{\rm SM}^{\rm FD}$')
ax[0,1].legend(loc=0)

"""
etau
"""
ax[1,0].plot(x_arr,yu_etau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1,0].plot(x_arr,yd_etau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1,0].plot(x_arr,ys_etau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1,0].plot(x_arr,yueqd_etau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1,0].plot(x_arr,yueqmd_etau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1,0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1,0].set_xlabel(r'$\epsilon_{e\tau}^{Aq}$')
ax[1,0].set_ylabel(r'$(\mathcal{N}^{\rm FD}-\mathcal{N}_{\rm SM}^{\rm FD})/\mathcal{N}_{\rm SM}^{\rm FD}$')
ax[1,0].legend(loc=0)

"""
mumu
"""
ax[1,1].plot(x_arr,yu_mumu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1,1].plot(x_arr,yd_mumu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1,1].plot(x_arr,ys_mumu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1,1].plot(x_arr,yueqd_mumu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1,1].plot(x_arr,yueqmd_mumu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1,1].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1,1].set_xlabel(r'$\epsilon_{\mu\mu}^{Aq}$')
ax[1,1].set_ylabel(r'$(\mathcal{N}^{\rm FD}-\mathcal{N}_{\rm SM}^{\rm FD})/\mathcal{N}_{\rm SM}^{\rm FD}$')
ax[1,1].legend(loc=0)

"""
mutau
"""
ax[2,1].plot(x_arr,yu_mutau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2,1].plot(x_arr,yd_mutau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2,1].plot(x_arr,ys_mutau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2,1].plot(x_arr,yueqd_mutau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2,1].plot(x_arr,yueqmd_mutau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2,1].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[2,1].set_xlabel(r'$\epsilon_{\mu\tau}^{Aq}$')
ax[2,1].set_ylabel(r'$(\mathcal{N}^{\rm FD}-\mathcal{N}_{\rm SM}^{\rm FD})/\mathcal{N}_{\rm SM}^{\rm FD}$')
ax[2,1].legend(loc=0)

"""
tautau
"""
ax[2,0].plot(x_arr,yu_tautau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2,0].plot(x_arr,yd_tautau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2,0].plot(x_arr,ys_tautau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2,0].plot(x_arr,yueqd_tautau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2,0].plot(x_arr,yueqmd_tautau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2,0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[2,0].set_xlabel(r'$\epsilon_{\tau\tau}^{Aq}$')
ax[2,0].set_ylabel(r'$(\mathcal{N}^{\rm FD}-\mathcal{N}_{\rm SM}^{\rm FD})/\mathcal{N}_{\rm SM}^{\rm FD}$')
ax[2,0].legend(loc=0)

plt.savefig('NumEveFD.pdf',bbox_inches='tight')
plt.show()

# %%
plt.rc('font', size=18)
fig, ax = plt.subplots(3,1,figsize=(7.25, 20))

"""
emu
"""
ax[0].plot(x_arr,yu_emu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0].plot(x_arr,yd_emu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0].plot(x_arr,ys_emu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0].plot(x_arr,yueqd_emu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0].plot(x_arr,yueqmd_emu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0].set_xlabel(r'$\epsilon_{e\mu}^{Aq}$')
ax[0].set_ylabel(r'$(\mathcal{N}^{\rm ND}-\mathcal{N}_{\rm SM}^{\rm ND})/\mathcal{N}_{\rm SM}^{\rm ND}$')
ax[0].legend(loc=0)

"""
mumu
"""
ax[1].plot(x_arr,yu_mumu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1].plot(x_arr,yd_mumu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1].plot(x_arr,ys_mumu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1].plot(x_arr,yueqd_mumu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1].plot(x_arr,yueqmd_mumu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1].set_xlabel(r'$\epsilon_{\mu\mu}^{Aq}$')
ax[1].set_ylabel(r'$(\mathcal{N}^{\rm ND}-\mathcal{N}_{\rm SM}^{\rm ND})/\mathcal{N}_{\rm SM}^{\rm ND}$')
ax[1].legend(loc=0)

"""
mutau
"""
ax[2].plot(x_arr,yu_mutau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2].plot(x_arr,yd_mutau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2].plot(x_arr,ys_mutau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2].plot(x_arr,yueqd_mutau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2].plot(x_arr,yueqmd_mutau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[2].set_xlabel(r'$\epsilon_{\mu\tau}^{Aq}$')
ax[2].set_ylabel(r'$(\mathcal{N}^{\rm ND}-\mathcal{N}_{\rm SM}^{\rm ND})/\mathcal{N}_{\rm SM}^{\rm ND}$')
ax[2].legend(loc=0)

plt.savefig('NND.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## DeltaFD

# %%
x_arr = []

"""
ee
"""
yu_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    x_arr.append(x)
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yu_ee_arr.append(y)

yd_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yd_ee_arr.append(y)

ys_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = x
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    ys_ee_arr.append(y)

yueqd_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqd_ee_arr.append(y)

yueqmd_ee_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = -x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqmd_ee_arr.append(y)

"""
emu
"""
yu_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yu_emu_arr.append(y)

yd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yd_emu_arr.append(y)

ys_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = x
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    ys_emu_arr.append(y)

yueqd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqd_emu_arr.append(y)

yueqmd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = -x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqmd_emu_arr.append(y)

"""
etau
"""
yu_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yu_etau_arr.append(y)

yd_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yd_etau_arr.append(y)

ys_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = x
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    ys_etau_arr.append(y)

yueqd_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqd_etau_arr.append(y)

yueqmd_etau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = -x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqmd_etau_arr.append(y)

"""
mumu
"""
yu_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yu_mumu_arr.append(y)

yd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yd_mumu_arr.append(y)

ys_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = x
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    ys_mumu_arr.append(y)

yueqd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqd_mumu_arr.append(y)

yueqmd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = -x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqmd_mumu_arr.append(y)

"""
mutau
"""
yu_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yu_mutau_arr.append(y)

yd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yd_mutau_arr.append(y)

ys_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = x
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    ys_mutau_arr.append(y)

yueqd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqd_mutau_arr.append(y)

yueqmd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = -x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqmd_mutau_arr.append(y)

"""
tautau
"""
yu_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yu_tautau_arr.append(y)

yd_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yd_tautau_arr.append(y)

ys_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = x
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    ys_tautau_arr.append(y)

yueqd_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqd_tautau_arr.append(y)

yueqmd_tautau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = -x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NFD(*arguments)-NbarFD(*arguments)
    DeltaNSM = NFD(*np.zeros(18))-NbarFD(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    yueqmd_tautau_arr.append(y)

# %%
plt.rc('font', size=18)
fig, ax = plt.subplots(3,2,figsize=(16, 20))

"""
ee
"""
ax[0,0].plot(x_arr,yu_ee_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0,0].plot(x_arr,yd_ee_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0,0].plot(x_arr,ys_ee_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0,0].plot(x_arr,yueqd_ee_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0,0].plot(x_arr,yueqmd_ee_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0,0].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0,0].set_xlabel(r'$\epsilon_{ee}^{Aq}$')
ax[0,0].set_ylabel(r'$\Delta \mathcal{N}^{\rm FD}/\Delta \mathcal{N}_{\rm SM}^{\rm FD}$')
ax[0,0].legend(loc=0)

"""
emu
"""
ax[0,1].plot(x_arr,yu_emu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0,1].plot(x_arr,yd_emu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0,1].plot(x_arr,ys_emu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0,1].plot(x_arr,yueqd_emu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0,1].plot(x_arr,yueqmd_emu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0,1].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0,1].set_xlabel(r'$\epsilon_{e\mu}^{Aq}$')
ax[0,1].set_ylabel(r'$\Delta \mathcal{N}^{\rm FD}/\Delta \mathcal{N}_{\rm SM}^{\rm FD}$')
ax[0,1].legend(loc=0)

"""
etau
"""
ax[1,0].plot(x_arr,yu_etau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1,0].plot(x_arr,yd_etau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1,0].plot(x_arr,ys_etau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1,0].plot(x_arr,yueqd_etau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1,0].plot(x_arr,yueqmd_etau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1,0].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1,0].set_xlabel(r'$\epsilon_{e\tau}^{Aq}$')
ax[1,0].set_ylabel(r'$\Delta \mathcal{N}^{\rm FD}/\Delta \mathcal{N}_{\rm SM}^{\rm FD}$')
ax[1,0].legend(loc=0)

"""
mumu
"""
ax[1,1].plot(x_arr,yu_mumu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1,1].plot(x_arr,yd_mumu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1,1].plot(x_arr,ys_mumu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1,1].plot(x_arr,yueqd_mumu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1,1].plot(x_arr,yueqmd_mumu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1,1].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1,1].set_xlabel(r'$\epsilon_{\mu\mu}^{Aq}$')
ax[1,1].set_ylabel(r'$\Delta \mathcal{N}^{\rm FD}/\Delta \mathcal{N}_{\rm SM}^{\rm FD}$')
ax[1,1].legend(loc=0)

"""
mutau
"""
ax[2,1].plot(x_arr,yu_mutau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2,1].plot(x_arr,yd_mutau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2,1].plot(x_arr,ys_mutau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2,1].plot(x_arr,yueqd_mutau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2,1].plot(x_arr,yueqmd_mutau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2,1].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[2,1].set_xlabel(r'$\epsilon_{\mu\tau}^{Aq}$')
ax[2,1].set_ylabel(r'$\Delta \mathcal{N}^{\rm FD}/\Delta \mathcal{N}_{\rm SM}^{\rm FD}$')
ax[2,1].legend(loc=0)

"""
tautau
"""
ax[2,0].plot(x_arr,yu_tautau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2,0].plot(x_arr,yd_tautau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2,0].plot(x_arr,ys_tautau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2,0].plot(x_arr,yueqd_tautau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2,0].plot(x_arr,yueqmd_tautau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2,0].axhline(y = 1,c='black',alpha=0.3,ls='dashed')
ax[2,0].set_xlabel(r'$\epsilon_{\tau\tau}^{Aq}$')
ax[2,0].set_ylabel(r'$\Delta \mathcal{N}^{\rm FD}/\Delta \mathcal{N}_{\rm SM}^{\rm FD}$')
ax[2,0].legend(loc=0)

plt.savefig('NumEveFDdelta.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ND and DeltaND tougher

# %%
x_arr = []

"""
emu
"""
yu_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    x_arr.append(x)
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_emu_arr.append(y)

yd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_emu_arr.append(y)

ys_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = x
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_emu_arr.append(y)

yueqd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_emu_arr.append(y)

yueqmd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = -x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_emu_arr.append(y)

"""
mumu
"""
yu_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_mumu_arr.append(y)

yd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_mumu_arr.append(y)

ys_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = x
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_mumu_arr.append(y)

yueqd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_mumu_arr.append(y)

yueqmd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = -x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_mumu_arr.append(y)

"""
mutau
"""
yu_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yu_mutau_arr.append(y)

yd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yd_mutau_arr.append(y)

ys_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = x
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    ys_mutau_arr.append(y)

yueqd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqd_mutau_arr.append(y)

yueqmd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = -x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    N = NND(*arguments)+NbarND(*arguments)
    NSM = NND(*np.zeros(18))+NbarND(*np.zeros(18))
    y = (N - NSM)/NSM 
    yueqmd_mutau_arr.append(y)

# %%
x_arr = []

"""
emu
"""
Tyu_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    x_arr.append(x)
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyu_emu_arr.append(y)

Tyd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyd_emu_arr.append(y)

Tys_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = x
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tys_emu_arr.append(y)

Tyueqd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyueqd_emu_arr.append(y)

Tyueqmd_emu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = -x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyueqmd_emu_arr.append(y)

"""
mumu
"""
Tyu_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyu_mumu_arr.append(y)

Tyd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyd_mumu_arr.append(y)

Tys_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = x
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tys_mumu_arr.append(y)

Tyueqd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyueqd_mumu_arr.append(y)

Tyueqmd_mumu_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = -x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyueqmd_mumu_arr.append(y)

"""
mutau
"""
Tyu_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyu_mutau_arr.append(y)

Tyd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyd_mutau_arr.append(y)

Tys_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = x
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tys_mutau_arr.append(y)

Tyueqd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyueqd_mutau_arr.append(y)

Tyueqmd_mutau_arr = []
for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = -x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    DeltaN = NND(*arguments)-NbarND(*arguments)
    DeltaNSM = NND(*np.zeros(18))-NbarND(*np.zeros(18))
    y = DeltaN/DeltaNSM 
    Tyueqmd_mutau_arr.append(y)

# %%
plt.rc('font', size=18)
fig, ax = plt.subplots(3,2,figsize=(16, 20))

"""
emu
"""
ax[0,0].plot(x_arr,yu_emu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0,0].plot(x_arr,yd_emu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0,0].plot(x_arr,ys_emu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0,0].plot(x_arr,yueqd_emu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0,0].plot(x_arr,yueqmd_emu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0,0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0,0].set_xlabel(r'$\epsilon_{e\mu}^{Aq}$')
ax[0,0].set_ylabel(r'$(\mathcal{N}^{\rm ND}-\mathcal{N}_{\rm SM}^{\rm ND})/\mathcal{N}_{\rm SM}^{\rm ND}$')
ax[0,0].legend(loc=0)

"""
emu
"""
ax[0,1].plot(x_arr,Tyu_emu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[0,1].plot(x_arr,Tyd_emu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[0,1].plot(x_arr,Tys_emu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[0,1].plot(x_arr,Tyueqd_emu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[0,1].plot(x_arr,Tyueqmd_emu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[0,1].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[0,1].set_xlabel(r'$\epsilon_{e\mu}^{Aq}$')
ax[0,1].set_ylabel(r'$\Delta \mathcal{N}^{\rm ND}/\Delta \mathcal{N}_{\rm SM}^{\rm ND}$')
ax[0,1].legend(loc=0)

"""
mumu
"""
ax[1,0].plot(x_arr,yu_mumu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1,0].plot(x_arr,yd_mumu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1,0].plot(x_arr,ys_mumu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1,0].plot(x_arr,yueqd_mumu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1,0].plot(x_arr,yueqmd_mumu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1,0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1,0].set_xlabel(r'$\epsilon_{\mu\mu}^{Aq}$')
ax[1,0].set_ylabel(r'$(\mathcal{N}^{\rm ND}-\mathcal{N}_{\rm SM}^{\rm ND})/\mathcal{N}_{\rm SM}^{\rm ND}$')
ax[1,0].legend(loc=0)

"""
mumu
"""
ax[1,1].plot(x_arr,Tyu_mumu_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[1,1].plot(x_arr,Tyd_mumu_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[1,1].plot(x_arr,Tys_mumu_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[1,1].plot(x_arr,Tyueqd_mumu_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[1,1].plot(x_arr,Tyueqmd_mumu_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[1,1].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[1,1].set_xlabel(r'$\epsilon_{\mu\mu}^{Aq}$')
ax[1,1].set_ylabel(r'$\Delta \mathcal{N}^{\rm ND}/\Delta \mathcal{N}_{\rm SM}^{\rm ND}$')
ax[1,1].legend(loc=0)

"""
mutau
"""
ax[2,0].plot(x_arr,yu_mutau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2,0].plot(x_arr,yd_mutau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2,0].plot(x_arr,ys_mutau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2,0].plot(x_arr,yueqd_mutau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2,0].plot(x_arr,yueqmd_mutau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2,0].axhline(y = 0,c='black',alpha=0.3,ls='dashed',lw=3)
ax[2,0].set_xlabel(r'$\epsilon_{\mu\tau}^{Aq}$')
ax[2,0].set_ylabel(r'$(\mathcal{N}^{\rm ND}-\mathcal{N}_{\rm SM}^{\rm ND})/\mathcal{N}_{\rm SM}^{\rm ND}$')
ax[2,0].legend(loc=0)

"""
mutau
"""
ax[2,1].plot(x_arr,Tyu_mutau_arr,c='C0',label=r'$\epsilon^{Au}$',lw=3)
ax[2,1].plot(x_arr,Tyd_mutau_arr,c='C1',label=r'$\epsilon^{Ad}$',lw=3)
ax[2,1].plot(x_arr,Tys_mutau_arr,c='C2',label=r'$\epsilon^{As}$',lw=3)
ax[2,1].plot(x_arr,Tyueqd_mutau_arr,c='C3',label=r'$\epsilon^{Au}=\epsilon^{Ad}$',lw=3)
ax[2,1].plot(x_arr,Tyueqmd_mutau_arr,c='C4',label=r'$\epsilon^{Au}=-\epsilon^{Ad}$',lw=3)
ax[2,1].axhline(y = 1,c='black',alpha=0.3,ls='dashed',lw=3)
ax[2,1].set_xlabel(r'$\epsilon_{\mu\tau}^{Aq}$')
ax[2,1].set_ylabel(r'$\Delta \mathcal{N}^{\rm ND}/\Delta \mathcal{N}_{\rm SM}^{\rm ND}$')
ax[2,1].legend(loc=0)

plt.savefig('NumEveNDtogether.pdf',bbox_inches='tight')
plt.show()
