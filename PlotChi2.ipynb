# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
x_steps = 60

eff = 90/100
sigma_eff = 10/100
sCC = 10/100
sQELRES = 10/100

# %% [markdown]
# ## Chi2 FD

# %% [markdown]
# ### Single flavor: u

# %%
"""
Chi2: ee
"""
x_final = 3
x_init = -x_final
xu_ee_arr = []
yu_ee_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xu_ee_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yu_ee_arr.append(y)

"""
Chi2: etau
"""
x_final = 0.4
x_init = -x_final
xu_etau_arr = []
yu_etau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xu_etau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yu_etau_arr.append(y)
    
"""
Chi2: tautau
"""
x_final = 0.15
x_init = -x_final
xu_tautau_arr = []
yu_tautau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xu_tautau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yu_tautau_arr.append(y)

# %%
"""
Chi2Pool: ee
"""
yu_ee_arr_pool = []

for x in xu_ee_arr:

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yu_ee_arr_pool.append(chi2)

"""
Chi2Pool: etau
"""
yu_etau_arr_pool = []

for x in xu_etau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yu_etau_arr_pool.append(chi2)
    
"""
Chi2Pool: tautau
"""
yu_tautau_arr_pool= []

for x in xu_tautau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yu_tautau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: ee
"""
ax1 = fig.add_subplot(311)
ax1.plot(xu_ee_arr,yu_ee_arr_pool,c='C0',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xu_ee_arr,yu_ee_arr,c='C0',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{ee}^{Au}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=4)

"""
Chi2: etau
"""
ax2 = fig.add_subplot(312)
ax2.plot(xu_etau_arr,yu_etau_arr_pool,c='C0',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xu_etau_arr,yu_etau_arr,c='C0',lw=3,ls='dotted',label=r'No uncertainty')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_xlabel(r'$\epsilon_{e\tau}^{Au}$')
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: tautau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xu_tautau_arr,yu_tautau_arr_pool,c='C0',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xu_tautau_arr,yu_tautau_arr,c='C0',lw=3,ls='dotted',label=r'No uncertainty')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_xlabel(r'$\epsilon_{\tau \tau}^{Au}$')
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)

plt.savefig('Chi2FD1u.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single flavor: d

# %%
"""
Chi2: ee
"""
x_final = 3
x_init = -x_final
xd_ee_arr = []
yd_ee_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xd_ee_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yd_ee_arr.append(y)

"""
Chi2: etau
"""
x_final = 0.3
x_init = -x_final
xd_etau_arr = []
yd_etau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xd_etau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yd_etau_arr.append(y)
    
"""
Chi2: tautau
"""
x_final = 0.4
x_init = -x_final
xd_tautau_arr = []
yd_tautau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xd_tautau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yd_tautau_arr.append(y)

# %%
"""
Chi2Pool: ee
"""
yd_ee_arr_pool = []

for x in xd_ee_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yd_ee_arr_pool.append(chi2)

"""
Chi2Pool: etau
"""
yd_etau_arr_pool = []
    
for x in xd_etau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yd_etau_arr_pool.append(chi2)
    
"""
Chi2Pool: tautau
"""
yd_tautau_arr_pool = []

for x in xd_tautau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yd_tautau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: ee
"""
ax1 = fig.add_subplot(311)
ax1.plot(xd_ee_arr,yd_ee_arr_pool,c='C1',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xd_ee_arr,yd_ee_arr,c='C1',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{ee}^{Ad}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=4)

"""
Chi2: etau
"""
ax2 = fig.add_subplot(312)
ax2.plot(xd_etau_arr,yd_etau_arr_pool,c='C1',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xd_etau_arr,yd_etau_arr,c='C1',lw=3,ls='dotted',label=r'No uncertainty')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_xlabel(r'$\epsilon_{e\tau}^{Ad}$')
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: tautau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xd_tautau_arr,yd_tautau_arr_pool,c='C1',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xd_tautau_arr,yd_tautau_arr,c='C1',lw=3,ls='dotted',label=r'No uncertainty')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_xlabel(r'$\epsilon_{\tau \tau}^{Ad}$')
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)

plt.savefig('Chi2FD1d.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single flavor: s

# %%
"""
Chi2: ee
"""
x_final = 8
x_init = -x_final
xs_ee_arr = []
ys_ee_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = x
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xs_ee_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    ys_ee_arr.append(y)

"""
Chi2: etau
"""
x_final = 1
x_init = -x_final
xs_etau_arr = []
ys_etau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = x
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xs_etau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    ys_etau_arr.append(y)
    
"""
Chi2: tautau
"""
x_final = 1.5
x_init = -x_final
xs_tautau_arr = []
ys_tautau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = x
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xs_tautau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    ys_tautau_arr.append(y)

# %%
"""
Chi2Pool: ee
"""

ys_ee_arr_pool = []

for x in xs_ee_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = x
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    ys_ee_arr_pool.append(chi2)

"""
Chi2Pool: etau
"""
ys_etau_arr_pool = []

for x in xs_etau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = x
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    ys_etau_arr_pool.append(chi2)
    
"""
Chi2Pool: tautau
"""
ys_tautau_arr_pool = []

for x in xs_tautau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = x
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    ys_tautau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: ee
"""
ax1 = fig.add_subplot(311)
ax1.plot(xs_ee_arr,ys_ee_arr_pool,c='C2',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xs_ee_arr,ys_ee_arr,c='C2',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{ee}^{As}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

"""
Chi2: etau
"""
ax2 = fig.add_subplot(312)
ax2.plot(xs_etau_arr,ys_etau_arr_pool,c='C2',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xs_etau_arr,ys_etau_arr,c='C2',lw=3,ls='dotted',label=r'No uncertainty')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_xlabel(r'$\epsilon_{e\tau}^{As}$')
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=4)

"""
Chi2: tautau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xs_tautau_arr,ys_tautau_arr_pool,c='C2',lw=3,label=r'\sigma_{\epsilon}=0.1$')
ax3.plot(xs_tautau_arr,ys_tautau_arr,c='C2',lw=3,ls='dotted',label=r'No uncertainty')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_xlabel(r'$\epsilon_{\tau \tau}^{As}$')
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)

plt.savefig('Chi2FD1s.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single flavor: u equal d

# %%
"""
Chi2: ee
"""
x_final = 2
x_init = -x_final
xueqd_ee_arr = []
yueqd_ee_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_ee_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_ee_arr.append(y)

"""
Chi2: etau
"""
x_final = 0.25
x_init = -x_final
xueqd_etau_arr = []
yueqd_etau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_etau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_etau_arr.append(y)
    
"""
Chi2: tautau
"""
x_final = 0.3
x_init = -x_final
xueqd_tautau_arr = []
yueqd_tautau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_tautau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_tautau_arr.append(y)

# %%
"""
Chi2Pool: ee
"""

yueqd_ee_arr_pool = []

for x in xueqd_ee_arr:

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_ee_arr_pool.append(chi2)

"""
Chi2Pool: etau
"""
yueqd_etau_arr_pool = []
    
for x in xueqd_etau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_etau_arr_pool.append(chi2)
    
"""
Chi2Pool: tautau
"""
yueqd_tautau_arr_pool = []
    
for x in xueqd_tautau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_tautau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: ee
"""
ax1 = fig.add_subplot(311)
ax1.plot(xueqd_ee_arr,yueqd_ee_arr_pool,c='C3',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xueqd_ee_arr,yueqd_ee_arr,c='C3',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{ee}^{Au}=\epsilon_{ee}^{Ad}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

"""
Chi2: etau
"""
ax2 = fig.add_subplot(312)
ax2.plot(xueqd_etau_arr,yueqd_etau_arr_pool,c='C3',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xueqd_etau_arr,yueqd_etau_arr,c='C3',lw=3,ls='dotted',label=r'No uncertainty')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_xlabel(r'$\epsilon_{e\tau}^{Au}=\epsilon_{e\tau}^{Ad}$')
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: tautau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xueqd_tautau_arr,yueqd_tautau_arr_pool,c='C3',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xueqd_tautau_arr,yueqd_tautau_arr,c='C3',lw=3,ls='dotted',label=r'No uncertainty')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_xlabel(r'$\epsilon_{\tau \tau}^{Au}=\epsilon_{\tau \tau}^{Ad}$')
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=4)

plt.savefig('Chi2FD1ueqd.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### The three flavors: u equal d

# %%
"""
Chi2
"""
x_final = 0.2
x_init = -x_final
xueqd_ee_taue_tautau_arr = []
yueqd_ee_taue_tautau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_ee_taue_tautau_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_ee_taue_tautau_arr.append(y)

# %%
"""
Chi2Pool
"""
yueqd_ee_taue_tautau_arr_pool = []

for x in xueqd_ee_taue_tautau_arr:

    epsilonAu_ee     = x
    epsilonAu_mue    = 0
    epsilonAu_taue   = x
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x
    
    epsilonAd_ee     = x
    epsilonAd_mue    = 0
    epsilonAd_taue   = x
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = x
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_ee_taue_tautau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 5.9))

"""
Chi2
"""
ax1 = fig.add_subplot(111)
ax1.plot(xueqd_ee_taue_tautau_arr,yueqd_ee_taue_tautau_arr_pool,c='C6',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xueqd_ee_taue_tautau_arr,yueqd_ee_taue_tautau_arr,c='C6',lw=3,ls='dotted',label=r'No uncertainty')
ax1.set_xlabel(r'$\epsilon_{ee, e\tau, \tau \tau}^{Au}=\epsilon_{ee, e\tau, \tau \tau}^{Ad}$')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=4)

plt.savefig('Chi2FD3ueqd.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Chi2 FD versus r

# %%
sol = -1.5

# %%
"""
Chi2
"""
x_steps = 90
yueqrd_tautau_arr = []
x_final = 10
x_init = -x_final
x_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x*sol/(x-1)
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = sol/(x-1)
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    x_arr.append(x)
    y = ((eff * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqrd_tautau_arr.append(y)

x_steps = 60

# %%
"""
Chi2Pool
"""
yueqrd_tautau_arr_pool = []

for x in x_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = x*sol/(x-1)
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = sol/(x-1)
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NFD(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarFD(*arguments)**2/(NbarFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NFD(*arguments)**2/(NFD(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NFD(*arguments) - eff * NFD(*np.zeros(18)))**2/(NFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarFD(*arguments) - eff * NbarFD(*np.zeros(18)))**2/(NbarFD(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqrd_tautau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 5.9))

"""
Chi2
"""
ax1 = fig.add_subplot(111)
ax1.plot(x_arr,yueqrd_tautau_arr_pool,c='C5',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(x_arr,yueqrd_tautau_arr,c='C5',lw=3,ls='dotted',label=r'No uncertainty')
ax1.set_xlabel(r'$r=\epsilon_{\tau \tau}^{Au}/\epsilon_{\tau \tau}^{Ad}$')
ax1.axvline(x = 1,c='k',alpha=0.3,lw=3,ls='dashed')
ax1.set_yscale('log')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(1e2,1e7)
ax1.legend(loc=2)

plt.savefig('Chi2FDr.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Chi2 ND

# %% [markdown]
# ### Single flavor: for u

# %%
"""
Chi2: mue
"""
x_final = 0.03
x_init = -x_final
xu_mue_arr = []
yu_mue_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xu_mue_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yu_mue_arr.append(y)

"""
Chi2: mumu
"""
x_final = 0.001
x_init = -x_final
xu_mumu_arr = []
yu_mumu_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xu_mumu_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yu_mumu_arr.append(y)
    
"""
Chi2: mutau
"""
x_final = 0.03
x_init = -x_final
xu_mutau_arr = []
yu_mutau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xu_mutau_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yu_mutau_arr.append(y)

# %%
"""
Chi2Pool: mue
"""
yu_mue_arr_pool = []

for x in xu_mue_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yu_mue_arr_pool.append(chi2)

"""
Chi2Pool: mumu
"""
yu_mumu_arr_pool = []

for x in xu_mumu_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yu_mumu_arr_pool.append(chi2)
    
"""
Chi2Pool: mutau
"""
yu_mutau_arr_pool = []

for x in xu_mutau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yu_mutau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: mue
"""
ax1 = fig.add_subplot(311)
ax1.plot(xu_mue_arr,yu_mue_arr_pool,c='C0',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xu_mue_arr,yu_mue_arr,c='C0',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{e \mu}^{Au}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

"""
Chi2: mumu
"""
ax2 = fig.add_subplot(312)
ax2.plot(xu_mumu_arr,yu_mumu_arr_pool,c='C0',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xu_mumu_arr,yu_mumu_arr,c='C0',lw=3,ls='dotted',label=r'No uncertainty')
ax2.set_xlabel(r'$\epsilon_{\mu \mu}^{Au}$')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: mutau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xu_mutau_arr,yu_mutau_arr_pool,c='C0',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xu_mutau_arr,yu_mutau_arr,c='C0',lw=3,ls='dotted',label=r'No uncertainty')
ax3.set_xlabel(r'$\epsilon_{\mu \tau}^{Au}$')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)

plt.savefig('Chi2ND1u.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single flavor: for d

# %%
"""
Chi2: mue
"""
x_final = 0.03
x_init = -x_final
xd_mue_arr = []
yd_mue_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xd_mue_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yd_mue_arr.append(y)

"""
Chi2: mumu
"""
x_final = 0.0035
x_init = -x_final
xd_mumu_arr = []
yd_mumu_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xd_mumu_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yd_mumu_arr.append(y)
    
"""
Chi2: mutau
"""
x_final = 0.03
x_init = -x_final
xd_mutau_arr = []
yd_mutau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xd_mutau_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yd_mutau_arr.append(y)

# %%
"""
Chi2Pool: mue
"""
yd_mue_arr_pool = []

for x in xd_mue_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yd_mue_arr_pool.append(chi2)

"""
Chi2Pool: mumu
"""
yd_mumu_arr_pool = []

for x in xd_mumu_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yd_mumu_arr_pool.append(chi2)
    
"""
Chi2Pool: mutau
"""
yd_mutau_arr_pool = []

for x in xd_mutau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yd_mutau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: mue
"""
ax1 = fig.add_subplot(311)
ax1.plot(xd_mue_arr,yd_mue_arr_pool,c='C1',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xd_mue_arr,yd_mue_arr,c='C1',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{e \mu}^{Ad}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

"""
Chi2: mumu
"""
ax2 = fig.add_subplot(312)
ax2.plot(xd_mumu_arr,yd_mumu_arr_pool,c='C1',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xd_mumu_arr,yd_mumu_arr,c='C1',lw=3,ls='dotted',label=r'No uncertainty')
ax2.set_xlabel(r'$\epsilon_{\mu \mu}^{Ad}$')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: mutau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xd_mutau_arr,yd_mutau_arr_pool,c='C1',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xd_mutau_arr,yd_mutau_arr,c='C1',lw=3,ls='dotted',label=r'No uncertainty')
ax3.set_xlabel(r'$\epsilon_{\mu \tau}^{Ad}$')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)

plt.savefig('Chi2ND1d.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single flavor: for s

# %%
"""
Chi2: mue
"""
x_final = 0.07
x_init = -x_final
xs_mue_arr = []
ys_mue_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = x
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xs_mue_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    ys_mue_arr.append(y)

"""
Chi2: mumu
"""
x_final = 0.003
x_init = -x_final
xs_mumu_arr = []
ys_mumu_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = x
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xs_mumu_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    ys_mumu_arr.append(y)
    
"""
Chi2: mutau
"""
x_final = 0.07
x_init = -x_final
xs_mutau_arr = []
ys_mutau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = x
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xs_mutau_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    ys_mutau_arr.append(y)

# %%
"""
Chi2Pool: mue
"""

ys_mue_arr_pool = []

for x in xs_mue_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = x
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    ys_mue_arr_pool.append(chi2)

"""
Chi2Pool: mumu
"""
ys_mumu_arr_pool = []

for x in xs_mumu_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = x
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    ys_mumu_arr_pool.append(chi2)
    
"""
Chi2Pool: mutau
"""

ys_mutau_arr_pool = []

for x in xs_mutau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = x
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    ys_mutau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: mue
"""

ax1 = fig.add_subplot(311)
ax1.plot(xs_mue_arr,ys_mue_arr_pool,c='C2',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xs_mue_arr,ys_mue_arr,c='C2',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{e \mu}^{As}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

"""
Chi2: mumu
"""

ax2 = fig.add_subplot(312)
ax2.plot(xs_mumu_arr,ys_mumu_arr_pool,c='C2',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xs_mumu_arr,ys_mumu_arr,c='C2',lw=3,ls='dotted',label=r'No uncertainty')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_xlabel(r'$\epsilon_{\mu \mu}^{As}$')
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: mutau
"""

ax3 = fig.add_subplot(313)
ax3.plot(xs_mutau_arr,ys_mutau_arr_pool,c='C2',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xs_mutau_arr,ys_mutau_arr,c='C2',lw=3,ls='dotted',label=r'No uncertainty')
ax3.set_xlabel(r'$\epsilon_{\mu \tau}^{As}$')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)

plt.savefig('Chi2ND1s.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Single flavor: for u equal d

# %%
"""
Chi2: mue
"""
x_final = 0.02
x_init = -x_final
xueqd_mue_arr = []
yueqd_mue_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_mue_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_mue_arr.append(y)

"""
Chi2: mumu
"""
x_final = 0.001  
x_init = -x_final
xueqd_mumu_arr = []
yueqd_mumu_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_mumu_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_mumu_arr.append(y)
    
"""
Chi2: mutau
"""
x_final = 0.02
x_init = -x_final
xueqd_mutau_arr = []
yueqd_mutau_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_mutau_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_mutau_arr.append(y)

# %%
"""
Chi2Pool: mue
"""

yueqd_mue_arr_pool = []

for x in xueqd_mue_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_mue_arr_pool.append(chi2)

"""
Chi2Pool: mumu
"""
yueqd_mumu_arr_pool = []

for x in xueqd_mumu_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = 0
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = 0
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_mumu_arr_pool.append(chi2)
    
"""
Chi2Pool: mutau
"""

yueqd_mutau_arr_pool = []

for x in xueqd_mutau_arr:
    
    epsilonAu_ee     = 0
    epsilonAu_mue    = 0
    epsilonAu_taue   = 0
    epsilonAu_mumu   = 0
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = 0
    epsilonAd_taue   = 0
    epsilonAd_mumu   = 0
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_mutau_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 20))

"""
Chi2: mue
"""
ax1 = fig.add_subplot(311)
ax1.plot(xueqd_mue_arr,yueqd_mue_arr_pool,c='C3',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xueqd_mue_arr,yueqd_mue_arr,c='C3',lw=3,ls='dotted',label=r'No uncertainty')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_xlabel(r'$\epsilon_{e \mu}^{Au}=\epsilon_{e \mu}^{Ad}$')
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

"""
Chi2: mumu
"""
ax2 = fig.add_subplot(312)
ax2.plot(xueqd_mumu_arr,yueqd_mumu_arr_pool,c='C3',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax2.plot(xueqd_mumu_arr,yueqd_mumu_arr,c='C3',lw=3,ls='dotted',label=r'No uncertainty')
ax2.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax2.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax2.set_xlabel(r'$\epsilon_{\mu \mu}^{Au}=\epsilon_{\mu \mu}^{Ad}$')
ax2.set_ylabel(r'$\chi^2$')
ax2.set_ylim(0,1.2*2.706)
ax2.legend(loc=3)

"""
Chi2: mutau
"""
ax3 = fig.add_subplot(313)
ax3.plot(xueqd_mutau_arr,yueqd_mutau_arr_pool,c='C3',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax3.plot(xueqd_mutau_arr,yueqd_mutau_arr,c='C3',lw=3,ls='dotted',label=r'No uncertainty')
ax3.set_xlabel(r'$\epsilon_{\mu \tau}^{Au}=\epsilon_{\mu \tau}^{Ad}$')
ax3.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax3.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax3.set_ylabel(r'$\chi^2$')
ax3.set_ylim(0,1.2*2.706)
ax3.legend(loc=3)


plt.savefig('Chi2ND1ueqd.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### The three flavors: for u equal d

# %%
"""
Chi2
"""
x_final = 0.001
x_init = -x_final
xueqd_mue_mumu_taumu_arr = []
yueqd_mue_mumu_taumu_arr = []

for x in np.arange (x_init,x_final+abs(x_final-x_init)/x_steps,abs(x_final-x_init)/x_steps):

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    xueqd_mue_mumu_taumu_arr.append(x)
    y = ((eff * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)) 
        +(eff * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12)))
    yueqd_mue_mumu_taumu_arr.append(y)

# %%
"""
Chi2Pool
"""
yueqd_mue_mumu_taumu_arr_pool = []

for x in xueqd_mue_mumu_taumu_arr:

    epsilonAu_ee     = 0
    epsilonAu_mue    = x
    epsilonAu_taue   = 0
    epsilonAu_mumu   = x
    epsilonAu_taumu  = x
    epsilonAu_tautau = 0
    
    epsilonAd_ee     = 0
    epsilonAd_mue    = x
    epsilonAd_taue   = 0
    epsilonAd_mumu   = x
    epsilonAd_taumu  = x
    epsilonAd_tautau = 0
    
    epsilonAs_ee     = 0
    epsilonAs_mue    = 0
    epsilonAs_taue   = 0
    epsilonAs_mumu   = 0
    epsilonAs_taumu  = 0
    epsilonAs_tautau = 0
    
    arguments = [epsilonAu_ee,epsilonAu_mue,epsilonAu_taue,epsilonAu_mumu,epsilonAu_taumu,epsilonAu_tautau,epsilonAd_ee,epsilonAd_mue,epsilonAd_taue,epsilonAd_mumu,epsilonAd_taumu,epsilonAd_tautau,epsilonAs_ee,epsilonAs_mue,epsilonAs_taue,epsilonAs_mumu,epsilonAs_taumu,epsilonAs_tautau]
    amin = ( (2*eff/sigma_eff**2 + 2*eff*NbarND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)+2*eff*NND(*arguments)/(eff+71/12*sCC+7/12*sQELRES)) 
     /(  2/sigma_eff**2 
       + 2*NbarND(*arguments)**2/(NbarND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) 
       + 2*NND(*arguments)**2/(NND(*np.zeros(18))*(eff+71/12*sCC+7/12*sQELRES)) ) )
    chi2 = ((amin * NND(*arguments) - eff * NND(*np.zeros(18)))**2/(NND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin * NbarND(*arguments) - eff * NbarND(*np.zeros(18)))**2/(NbarND(*np.zeros(18)) * (eff + sCC * 71/12 + sQELRES * 7/12))
           +(amin - eff)**2/sigma_eff**2)
    yueqd_mue_mumu_taumu_arr_pool.append(chi2)

# %%
plt.rc('font', size=18)
plt.rc('ytick', labelsize=12)
fig = plt.figure(figsize=(16, 5.9))

"""
Chi2
"""
ax1 = fig.add_subplot(111)
ax1.plot(xueqd_mue_mumu_taumu_arr,yueqd_mue_mumu_taumu_arr_pool,c='C6',lw=3,label=r'$\sigma_{\epsilon}=0.1$')
ax1.plot(xueqd_mue_mumu_taumu_arr,yueqd_mue_mumu_taumu_arr,c='C6',lw=3,ls='dotted',label=r'No uncertainty')
ax1.set_xlabel(r'$\epsilon_{e \mu, \mu \mu, \mu \tau}^{Au}=\epsilon_{e \mu, \mu \mu, \mu \tau}^{Ad}$')
ax1.axhline(y = 2.706,c='k',alpha=0.5,lw=3,ls='dashed')
ax1.annotate('90% C.L.', xy=(0,1.02*2.706),ha='center', xycoords='data',c='k',alpha=0.5)
ax1.set_ylabel(r'$\chi^2$')
ax1.set_ylim(0,1.2*2.706)
ax1.legend(loc=3)

plt.savefig('Chi2ND3ueqd.pdf',bbox_inches='tight')
plt.show()
